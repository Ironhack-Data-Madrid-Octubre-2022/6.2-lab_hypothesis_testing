# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Exploring the Data
#
# In this challenge, we will examine all salaries of employees of the City of Chicago. We will start by loading the dataset and examining its contents

# %%
# Run this code:
salaries = pd.read_csv('../Current_Employee_Names__Salaries__and_Position_Titles.csv',encoding='latin1')

# %% [markdown]
# Examine the `salaries` dataset using the `head` function below.

# %%
salaries.head()
# Out:
#                   Name                              Job Titles  \
# 0    AARON,  JEFFERY M                                SERGEANT
# 1      AARON,  KARINA   POLICE OFFICER (ASSIGNED AS DETECTIVE)
# 2  AARON,  KIMBERLEI R                CHIEF CONTRACT EXPEDITER
# 3  ABAD JR,  VICENTE M                       CIVIL ENGINEER IV
# 4    ABASCAL,  REECE E             TRAFFIC CONTROL AIDE-HOURLY
#
#          Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 0            POLICE                 F           Salary            NaN
# 1            POLICE                 F           Salary            NaN
# 2  GENERAL SERVICES                 F           Salary            NaN
# 3       WATER MGMNT                 F           Salary            NaN
# 4              OEMC                 P           Hourly           20.0
#
#    Annual Salary  Hourly Rate
# 0       101442.0          NaN
# 1        94122.0          NaN
# 2       101592.0          NaN
# 3       110064.0          NaN
# ...

# %% [markdown]
# We see from looking at the `head` function that there is quite a bit of missing data. Let's examine how much missing data is in each column. Produce this output in the cell below

# %%
salaries.tail()
# Out:
#                         Name               Job Titles Department  \
# 33178  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 33179     ZYMANTAS,  LAURA C           POLICE OFFICER     POLICE
# 33180      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 33181    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 33182   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 33178                 F           Salary            NaN        72510.0
# 33179                 F           Salary            NaN        48078.0
# 33180                 F           Salary            NaN        90024.0
# 33181                 F           Salary            NaN        93354.0
# 33182                 F           Salary            NaN       115932.0
#
#        Hourly Rate
# 33178          NaN
# 33179          NaN
# 33180          NaN
# 33181          NaN
# 33182          NaN

# %% [markdown]
# Let's also look at the count of hourly vs. salaried employees. Write the code in the cell below

# %%
salaries['Salary or Hourly'].value_counts()
# Out:
# Salary    25161
# Hourly     8022
# Name: Salary or Hourly, dtype: int64

# %% [markdown]
# What this information indicates is that the table contains information about two types of employees - salaried and hourly. Some columns apply only to one type of employee while other columns only apply to another kind. This is why there are so many missing values. Therefore, we will not do anything to handle the missing values.

# %% [markdown]
# There are different departments in the city. List all departments and the count of employees in each department.

# %%
salaries['Department'].value_counts()
# Out:
# POLICE                   13414
# FIRE                      4641
# STREETS & SAN             2198
# OEMC                      2102
# WATER MGMNT               1879
# AVIATION                  1629
# TRANSPORTN                1140
# PUBLIC LIBRARY            1015
# GENERAL SERVICES           980
# FAMILY & SUPPORT           615
# FINANCE                    560
# HEALTH                     488
# CITY COUNCIL               411
# LAW                        407
# BUILDINGS                  269
# COMMUNITY DEVELOPMENT      207
# BUSINESS AFFAIRS           171
# COPA                       116
# BOARD OF ELECTION          107
# DoIT                        99
# PROCUREMENT                 92
# INSPECTOR GEN               87
# MAYOR'S OFFICE              85
# CITY CLERK                  84
# ANIMAL CONTRL               81
# HUMAN RESOURCES             79
# CULTURAL AFFAIRS            65
# BUDGET & MGMT               46
# ADMIN HEARNG                39
# DISABILITIES                28
# ...

# %% [markdown]
# # Challenge 2 - Hypothesis Tests
#
# In this section of the lab, we will test whether the hourly wage of all hourly workers is significantly different from $30/hr. Import the correct one sample test function from scipy and perform the hypothesis test for a 95% two sided confidence interval.

# %%
import pylab as plt
from scipy.stats import norm
import pandas as pd

from scipy.stats import ttest_rel  # testeo con dos muestras dependientes

from scipy.stats import ttest_ind  # testeo con dos muestras independientes

# %%
hour = salaries['Salary or Hourly'][(salaries['Salary or Hourly'] == 'Hourly')].index

# %%
hour
# Out:
# Int64Index([    4,     6,     7,    10,    18,    19,    21,    24,    26,
#                33,
#             ...
#             33149, 33150, 33156, 33158, 33161, 33164, 33168, 33169, 33174,
#             33175],
#            dtype='int64', length=8022)

# %%
salaries.columns
# Out:
# Index(['Name', 'Job Titles', 'Department', 'Full or Part-Time',
#        'Salary or Hourly', 'Typical Hours', 'Annual Salary', 'Hourly Rate'],
#       dtype='object')

# %%
hours = salaries.loc[hour][['Name', 'Job Titles', 'Department', 'Full or Part-Time',
       'Salary or Hourly', 'Typical Hours', 'Hourly Rate']]

# %%
hours.head(10)
# Out:
#                       Name                        Job Titles  \
# 4        ABASCAL,  REECE E       TRAFFIC CONTROL AIDE-HOURLY
# 6    ABBATACOLA,  ROBERT J               ELECTRICAL MECHANIC
# 7       ABBATE,  JOSEPH L            POOL MOTOR TRUCK DRIVER
# 10        ABBOTT,  BETTY L                FOSTER GRANDPARENT
# 18    ABDULLAH,  LAKENYA N                    CROSSING GUARD
# 19      ABDULLAH,  RASHAD   ELECTRICAL MECHANIC (AUTOMOTIVE)
# 21   ABDUL-SHAKUR,  TAHIR              GENERAL LABORER - DSS
# 24  ABERCROMBIE,  TIMOTHY                 MOTOR TRUCK DRIVER
# 26      ABIOYE,  ADEWOLE A        LIBRARY ASSOCIATE - HOURLY
# 33  ABRAHAMSON,  MICHAEL C  STUDENT INTERN - MAYOR'S FELLOWS
#
#           Department Full or Part-Time Salary or Hourly  Typical Hours  \
# 4               OEMC                 P           Hourly           20.0
# 6           AVIATION                 F           Hourly           40.0
# 7      STREETS & SAN                 F           Hourly           40.0
# ...

# %%
hours['Hourly Rate'].mean()
# Out:
# 32.78855771628128

# %%
from scipy.stats import ttest_1samp

# %%
t_test=ttest_1samp(hours['Hourly Rate'], 30)

t_test
# Out:
# Ttest_1sampResult(statistic=20.6198057854942, pvalue=4.3230240486229894e-92)

# %% [markdown]
# We are also curious about salaries in the police force. The chief of police in Chicago claimed in a press briefing that salaries this year are higher than last year's mean of $86000/year a year for all salaried employees. Test this one sided hypothesis using a 95% confidence interval.
#
# Hint: A one tailed test has a p-value that is half of the two tailed p-value. If our hypothesis is greater than, then to reject, the test statistic must also be positive.

# %%
salaries[(salaries.Department == 'POLICE')&(salaries['Salary or Hourly'])]['Annual Salary'].mean()
# Out:
# 86486.41450313339

# %%
s2 = list(salaries[(salaries.Department == 'POLICE')&(salaries['Salary or Hourly']=='Salary')]['Annual Salary']) ### IMPORTANTE CONVERTIR A LISTA
s2
# Out:
# [101442.0,
#  94122.0,
#  93354.0,
#  84054.0,
#  87006.0,
#  84054.0,
#  90024.0,
#  48078.0,
#  76266.0,
#  48078.0,
#  80016.0,
#  72510.0,
#  68616.0,
#  90024.0,
#  48078.0,
#  76266.0,
#  48078.0,
#  72510.0,
#  97440.0,
#  72510.0,
#  87006.0,
#  90024.0,
#  84054.0,
#  87006.0,
#  90024.0,
#  72510.0,
#  87006.0,
#  43800.0,
#  76266.0,
#  84054.0,
#  84054.0,
#  90024.0,
#  100980.0,
#  90024.0,
#  90024.0,
#  90024.0,
#  87006.0,
#  93354.0,
#  93354.0,
#  72510.0,
#  93354.0,
#  50676.0,
#  87006.0,
#  72510.0,
#  90024.0,
#  72510.0,
#  84054.0,
#  94524.0,
#  48078.0,
#  90024.0,
#  100980.0,
#  96060.0,
#  100776.0,
#  87006.0,
#  40392.0,
#  48078.0,
#  68616.0,
#  100980.0,
#  93354.0,
#  48078.0,
#  48078.0,
#  84054.0,
#  76266.0,
#  84054.0,
#  97440.0,
#  90024.0,
#  94524.0,
#  84054.0,
#  111474.0,
#  90024.0,
#  50676.0,
#  96060.0,
#  91338.0,
#  96060.0,
#  111474.0,
#  93354.0,
#  87006.0,
#  96060.0,
#  103932.0,
#  94524.0,
#  111474.0,
#  87006.0,
# ...

# %%
mu = 86000
t_test=ttest_1samp(s2, mu,alternative='greater' )
t_test
# Out:
# Ttest_1sampResult(statistic=3.081997005712994, pvalue=0.0010301701775482569)

# %% [markdown]
# ### el pvalue = 0,001 es inferior a 0,05 damos por valido la hipotesis del h1
# ### h1 reta a h0
# ### h1 dice que su hipotesis es mayor que que h0, de ahi el alternative = greater
# 0,001<0.05

# %% [markdown]
# Using the `crosstab` function, find the department that has the most hourly workers.

# %%
crosstab = pd.crosstab(index=salaries.Department, columns=salaries[salaries['Salary or Hourly']=='Hourly']['Salary or Hourly'])
crosstab
# Out:
# Salary or Hourly       Hourly
# Department
# ANIMAL CONTRL              19
# AVIATION                 1082
# BUDGET & MGMT               2
# BUSINESS AFFAIRS            7
# CITY COUNCIL               64
# COMMUNITY DEVELOPMENT       4
# CULTURAL AFFAIRS            7
# FAMILY & SUPPORT          287
# FINANCE                    44
# FIRE                        2
# GENERAL SERVICES          765
# HEALTH                      3
# HUMAN RESOURCES             4
# LAW                        40
# MAYOR'S OFFICE              8
# OEMC                     1273
# POLICE                     10
# PROCUREMENT                 2
# PUBLIC LIBRARY            299
# STREETS & SAN            1862
# TRANSPORTN                725
# WATER MGMNT              1513

# %% [markdown]
# ###  ORDENAR POR ASCENDENTE/DESCENTE

# %%
crosstab.Hourly.sort_values(ascending=False)
# Out:
# Department
# STREETS & SAN            1862
# WATER MGMNT              1513
# OEMC                     1273
# AVIATION                 1082
# GENERAL SERVICES          765
# TRANSPORTN                725
# PUBLIC LIBRARY            299
# FAMILY & SUPPORT          287
# CITY COUNCIL               64
# FINANCE                    44
# LAW                        40
# ANIMAL CONTRL              19
# POLICE                     10
# MAYOR'S OFFICE              8
# CULTURAL AFFAIRS            7
# BUSINESS AFFAIRS            7
# HUMAN RESOURCES             4
# COMMUNITY DEVELOPMENT       4
# HEALTH                      3
# FIRE                        2
# PROCUREMENT                 2
# BUDGET & MGMT               2
# Name: Hourly, dtype: int64

# %% [markdown]
# The workers from the department with the most hourly workers have complained that their hourly wage is less than $35/hour. Using a one sample t-test, test this one-sided hypothesis at the 95% confidence level.

# %%
s3 = salaries['Hourly Rate'][(salaries.Department == 'STREETS & SAN')&(salaries['Salary or Hourly']=='Hourly')]

# %%
s3
# Out:
# 7        35.60
# 21       21.43
# 24       35.60
# 36       36.21
# 39       35.60
#          ...
# 33106    36.13
# 33107    35.60
# 33147    35.60
# 33149    36.21
# 33156    22.12
# Name: Hourly Rate, Length: 1862, dtype: float64

# %%
t_test=ttest_1samp(s3, 35,alternative='less' )

t_test
# Out:
# Ttest_1sampResult(statistic=-9.567447887848152, pvalue=1.6689265282353859e-21)

# %% [markdown]
# ### h1 los trabajadores por horas dicen que la media de hora es menor de 35 de ahi alternative = 'less'
# ### el pvalue es inferior a 0.05 por lo tanto nos quedamos con la hipotesis h1
# ## pvalue es el porcentaje que falta para que la hipotesis h1 se cumpla en el 100% real
# ### cuando pvalue es 0.05 admites que hay un 5% de la probabilidad de la hipotesis sea 100% cierta

# %% [markdown]
# # Challenge 3 - Constructing Confidence Intervals
#
# While testing our hypothesis is a great way to gather empirical evidence for accepting or rejecting the hypothesis, another way to gather evidence is by creating a confidence interval. A confidence interval gives us information about the true mean of the population. So for a 95% confidence interval, we are 95% sure that the mean of the population is within the confidence interval.
# ).
#
# To read more about confidence intervals, click [here](https://en.wikipedia.org/wiki/Confidence_interval).
#
#
# In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers.
#
# The confidence interval is computed in SciPy using the `t.interval` function. You can read more about this function [here](https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.t.html).
#
# To compute the confidence interval of the hourly wage, use the 0.95 for the confidence level, number of rows - 1 for degrees of freedom, the mean of the sample for the location parameter and the standard error for the scale. The standard error can be computed using [this](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.sem.html) function in SciPy.

# %%
from scipy.stats import sem 
from scipy.stats import norm
from scipy.stats import t

# %%
### 'In the cell below, we will construct a 95% confidence interval for the mean hourly wage of all hourly workers. '
### UTILIZAMOS hourly rate debido a a que te pide la media de salario por horas de los trabajadores por horas


t.interval(0.95, len(hours['Hourly Rate'])-1, loc=hours['Hourly Rate'].mean(), scale=sem(hours['Hourly Rate']))
# Out:
# (32.52345834488529, 33.05365708767727)

# %% [markdown]
# Now construct the 95% confidence interval for all salaried employeed in the police in the cell below.

# %%
t.interval(0.95, len(s2)-1, loc=salaries[(salaries.Department == 'POLICE')&(salaries['Salary or Hourly']=='Salary')]['Annual Salary'].mean(), scale=sem(s2))
# Out:
# (86177.05631531784, 86795.77269094894)

# %% [markdown]
# # Challenge 4 - Hypothesis Tests of Proportions
#
# Another type of one sample test is a hypothesis test of proportions. In this test, we examine whether the proportion of a group in our sample is significantly different than a fraction.
#
# You can read more about one sample proportion tests [here](http://sphweb.bumc.bu.edu/otlt/MPH-Modules/BS/SAS/SAS6-CategoricalData/SAS6-CategoricalData2.html).
#
# In the cell below, use the `proportions_ztest` function from `statsmodels` to perform a hypothesis test that will determine whether the number of hourly workers in the City of Chicago is significantly different from 25% at the 95% confidence level.

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
salaries['Salary or Hourly'].value_counts()
# Out:
# Salary    25161
# Hourly     8022
# Name: Salary or Hourly, dtype: int64

# %%
proportions_ztest(salaries['Salary or Hourly'].value_counts()[1], len(salaries), 0.25)
# Out:
# (-3.5099964213703005, 0.0004481127249057967)

# %% [markdown]
# ### ¿La proporcion entre asalariados y trabajadores por horas es del 25%?
